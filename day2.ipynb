# %%
num=[1,2,3,4]
num.append(10)
print(num)
# Out:
# [1, 2, 3, 4, 10]

# %%
num=[1,2,3,4]
num.pop(0)
print(num)
# Out:
# [2, 3, 4]

# %%
num.insert(5,100)
print(num)
# Out:
# [2, 100, 100, 100, 3, 100, 4]

# %%
num.sort()
print(num)
# Out:
# [2, 3, 4, 100, 100, 100, 100]

# %%
print(num[1:4])
# Out:
# [3, 4, 100]

# %%
squares=[i**2 for i in range(1,11)]
print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
evens=[i for i in range(1,10) if i%2==0]
print(evens)
# Out:
# [2, 4, 6, 8]
